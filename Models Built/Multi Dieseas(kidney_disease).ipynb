# %% [markdown]
# ## **Data Cleaning**

# %%
import pandas as pd

df=pd.read_csv('/content/kidney_disease.csv')
pd.set_option('display.max_columns', None)
df.tail()
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#        bgr    bu   sc    sod  pot  hemo pcv    wc   rc htn  dm cad appet  pe  \
# 395  140.0  49.0  0.5  150.0  4.9  15.7  47  6700  4.9  no  no  no  good  no
# 396   75.0  31.0  1.2  141.0  3.5  16.5  54  7800  6.2  no  no  no  good  no
# 397  100.0  26.0  0.6  137.0  4.4  15.8  49  6600  5.4  no  no  no  good  no
# 398  114.0  50.0  1.0  135.0  4.9  14.2  51  7200  5.9  no  no  no  good  no
# 399  131.0  18.0  1.1  141.0  3.5  15.8  53  6800  6.1  no  no  no  good  no
#
#     ane classification
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.drop(['id'],axis=1,inplace=True)

# %%
import matplotlib.pyplot as plt

plt.hist(df['age'],bins=50)
plt.show()

# %%
df['age'].fillna(df['age'].median(),inplace=True)
# Out:
# /tmp/ipython-input-2790788646.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(),inplace=True)

# %%
df['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
plt.hist(df['bp'],bins=50)
plt.show()

# %%
df['bp'].fillna(df['bp'].median(),inplace=True)
# Out:
# /tmp/ipython-input-4106292725.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bp'].fillna(df['bp'].median(),inplace=True)

# %%
df['bp'].isnull().sum()
# Out:
# np.int64(0)

# %%
import warnings
warnings.filterwarnings('ignore')

plt.hist(df['sg'],bins=50)
plt.show()

# %%
df['sg'].value_counts()
# Out:
# sg
# 1.020    106
# 1.010     84
# 1.025     81
# 1.015     75
# 1.005      7
# Name: count, dtype: int64

# %%
df['sg'].isnull().sum()
# Out:
# np.int64(47)

# %%
df['sg'].fillna(df['sg'].mode()[0],inplace=True)

# %%
df['sg'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['al'].isnull().sum()
# Out:
# np.int64(46)

# %%
df['al'].value_counts()
# Out:
# al
# 0.0    199
# 1.0     44
# 3.0     43
# 2.0     43
# 4.0     24
# 5.0      1
# Name: count, dtype: int64

# %%
df['al'].fillna(df['al'].mode()[0],inplace=True)

# %% [markdown]
# ## **EDA**

# %%
# !pip install ydata-profiling -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.7/398.7 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 72.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 35.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.6 MB/s eta 0:00:00

# %%
#filling nan values with EDA analysis

import ydata_profiling as yd

profile=yd.ProfileReport(df)
profile
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df['su'].fillna(df['su'].mode()[0],inplace=True)

# %%
df['rbc'].fillna(df['rbc'].mode()[0],inplace=True)

# %%
df['pc'].fillna(df['pc'].mode()[0],inplace=True)

# %%
df['pcc'].fillna(df['pcc'].mode()[0],inplace=True)

# %%
df['ba'].fillna(df['ba'].mode()[0],inplace=True)

# %%
df['bgr'].fillna(df['bgr'].median(),inplace=True)

# %%
df['bu'].fillna(df['bu'].median(),inplace=True)

# %%
df['sc'].fillna(df['sc'].median(),inplace=True)

# %%
df['sod'].fillna(df['sod'].median(),inplace=True)

# %%
df['pot'].fillna(df['pot'].median(),inplace=True)

# %%
df['hemo'].fillna(df['hemo'].median(),inplace=True)

# %%
df['pcv'].value_counts()
# Out:
# pcv
# 52    21
# 41    21
# 44    19
# 48    19
# 40    16
# 43    15
# 45    13
# 42    13
# 28    12
# 36    12
# 32    12
# 33    12
# 50    12
# 34    11
# 37    11
# 35     9
# 29     9
# 46     9
# 30     9
# 31     8
# 24     7
# 39     7
# 26     6
# 38     5
# 54     4
# 53     4
# 49     4
# 47     4
# 51     4
# 22     3
# 25     3
# 27     3
# 19     2
# 23     2
# 16     1
# 17     1
# 18     1
# ?      1
# 14     1
# 21     1
# 15     1
# 9      1
# 20     1
# Name: count, dtype: int64

# %%
df[df['pcv']=='?']
# Out:
#      age    bp    sg   al   su       rbc      pc         pcc          ba  \
# 66  67.0  70.0  1.02  2.0  0.0  abnormal  normal  notpresent  notpresent
#
#       bgr    bu   sc    sod  pot   hemo pcv   wc   rc  htn   dm cad appet  \
# 66  150.0  55.0  1.6  131.0  4.8  12.65   ?  NaN  NaN  yes  yes  no  good
#
#      pe ane classification
# 66  yes  no            ckd

# %%
df['pcv'].replace('?','43',inplace=True)

# %%
df['pcv']=df['pcv'].astype('float64')

# %%
df['pcv'].fillna(df['pcv'].median(),inplace=True)

# %%
df['wc'].value_counts()
# Out:
# wc
# 9800    11
# 6700    10
# 9200     9
# 9600     9
# 7200     9
#         ..
# 9900     1
# 5900     1
# 5200     1
# 9700     1
# 5100     1
# Name: count, Length: 90, dtype: int64

# %%
import numpy as np

df['wc'].replace('?',np.nan,inplace=True)

# %%
df['wc']=df['wc'].astype('float64')

# %%
plt.hist(df['wc'],bins=50)
plt.show()

# %%
df['wc'].fillna(df['wc'].median(),inplace=True)

# %%
df['rc'].replace('?',np.nan,inplace=True)

# %%
df['rc']=df['rc'].astype('float64')

# %%
plt.hist(df['rc'],bins=50)
plt.show()

# %%
df['rc'].fillna(df['rc'].median(),inplace=True)

# %%
df['htn'].fillna(df['htn'].mode()[0],inplace=True)
df['dm'].fillna(df['dm'].mode()[0],inplace=True)
df['cad'].fillna(df['cad'].mode()[0],inplace=True)
df['appet'].fillna(df['appet'].mode()[0],inplace=True)
df['pe'].fillna(df['pe'].mode()[0],inplace=True)
df['ane'].fillna(df['ane'].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             400 non-null    float64
#  1   bp              400 non-null    float64
#  2   sg              400 non-null    float64
#  3   al              400 non-null    float64
#  4   su              400 non-null    float64
#  5   rbc             400 non-null    object
#  6   pc              400 non-null    object
#  7   pcc             400 non-null    object
#  8   ba              400 non-null    object
#  9   bgr             400 non-null    float64
#  10  bu              400 non-null    float64
#  11  sc              400 non-null    float64
#  12  sod             400 non-null    float64
#  13  pot             400 non-null    float64
#  14  hemo            400 non-null    float64
#  15  pcv             400 non-null    float64
#  16  wc              400 non-null    float64
# ...

# %%
profile_report=yd.ProfileReport(df)
profile_report
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ### **Encoding**

# %%
df.head(10)
# Out:
#     age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 0  48.0   80.0  1.020  1.0  0.0    normal    normal  notpresent  notpresent
# 1   7.0   50.0  1.020  4.0  0.0    normal    normal  notpresent  notpresent
# 2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent
# 3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 5  60.0   90.0  1.015  3.0  0.0    normal    normal  notpresent  notpresent
# 6  68.0   70.0  1.010  0.0  0.0    normal    normal  notpresent  notpresent
# 7  24.0   80.0  1.015  2.0  4.0    normal  abnormal  notpresent  notpresent
# 8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present  notpresent
# 9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
#
#      bgr     bu    sc    sod  pot  hemo   pcv       wc   rc  htn   dm cad  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
for col in ['rbc','pc','pcc','ba','htn','dm','cad','appet','pe','ane']:
  df[col]=le.fit_transform(df[col])

# %%
df['classification'] = df['classification'].map({'ckd': 1, 'notckd': 0})

# %%
df.head(10)
# Out:
#     age     bp     sg   al   su  rbc  pc  pcc  ba    bgr     bu    sc    sod  \
# 0  48.0   80.0  1.020  1.0  0.0    1   1    0   0  121.0   36.0   1.2  138.0
# 1   7.0   50.0  1.020  4.0  0.0    1   1    0   0  121.0   18.0   0.8  138.0
# 2  62.0   80.0  1.010  2.0  3.0    1   1    0   0  423.0   53.0   1.8  138.0
# 3  48.0   70.0  1.005  4.0  0.0    1   0    1   0  117.0   56.0   3.8  111.0
# 4  51.0   80.0  1.010  2.0  0.0    1   1    0   0  106.0   26.0   1.4  138.0
# 5  60.0   90.0  1.015  3.0  0.0    1   1    0   0   74.0   25.0   1.1  142.0
# 6  68.0   70.0  1.010  0.0  0.0    1   1    0   0  100.0   54.0  24.0  104.0
# 7  24.0   80.0  1.015  2.0  4.0    1   0    0   0  410.0   31.0   1.1  138.0
# 8  52.0  100.0  1.015  3.0  0.0    1   0    1   0  138.0   60.0   1.9  138.0
# 9  53.0   90.0  1.020  2.0  0.0    0   0    1   0   70.0  107.0   7.2  114.0
#
#    pot  hemo   pcv       wc   rc  htn  dm  cad  appet  pe  ane  classification
# ...

# %% [markdown]
# ### **Feature selection**

# %%
cor=df.corr()
cor['classification'].sort_values(ascending=False)
# Out:
# classification    1.000000
# htn               0.590438
# dm                0.559060
# al                0.531562
# appet             0.393341
# bgr               0.379321
# pe                0.375154
# bu                0.369393
# ane               0.325396
# su                0.294555
# bp                0.293693
# sc                0.291245
# pcc               0.265313
# cad               0.236088
# age               0.227842
# ba                0.186871
# wc                0.177571
# pot               0.065218
# rbc              -0.282642
# sod              -0.334900
# pc               -0.375154
# rc               -0.566163
# sg               -0.659504
# pcv              -0.672233
# hemo             -0.726368
# Name: classification, dtype: float64

# %%
x=df.drop(['pot','wc','ba','classification'],axis=1)
y=df['classification']

# %%
x.head()
# Out:
#     age    bp     sg   al   su  rbc  pc  pcc    bgr    bu   sc    sod  hemo  \
# 0  48.0  80.0  1.020  1.0  0.0    1   1    0  121.0  36.0  1.2  138.0  15.4
# 1   7.0  50.0  1.020  4.0  0.0    1   1    0  121.0  18.0  0.8  138.0  11.3
# 2  62.0  80.0  1.010  2.0  3.0    1   1    0  423.0  53.0  1.8  138.0   9.6
# 3  48.0  70.0  1.005  4.0  0.0    1   0    1  117.0  56.0  3.8  111.0  11.2
# 4  51.0  80.0  1.010  2.0  0.0    1   1    0  106.0  26.0  1.4  138.0  11.6
#
#     pcv   rc  htn  dm  cad  appet  pe  ane
# 0  44.0  5.2    1   1    0      0   0    0
# 1  38.0  4.8    0   0    0      0   0    0
# 2  31.0  4.8    0   1    0      1   0    1
# 3  32.0  3.9    1   0    0      1   1    1
# 4  35.0  4.6    0   0    0      0   0    0

# %% [markdown]
# ### **Balancing Data**

# %%
y.value_counts()
# Out:
# classification
# 1    250
# 0    150
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

smote=SMOTE()
x_smote,y_smote=smote.fit_resample(x,y)

# %%
y_smote.value_counts()
# Out:
# classification
# 1    250
# 0    250
# Name: count, dtype: int64

# %%
x_smote.head()
# Out:
#     age    bp     sg   al   su  rbc  pc  pcc    bgr    bu   sc    sod  hemo  \
# 0  48.0  80.0  1.020  1.0  0.0    1   1    0  121.0  36.0  1.2  138.0  15.4
# 1   7.0  50.0  1.020  4.0  0.0    1   1    0  121.0  18.0  0.8  138.0  11.3
# 2  62.0  80.0  1.010  2.0  3.0    1   1    0  423.0  53.0  1.8  138.0   9.6
# 3  48.0  70.0  1.005  4.0  0.0    1   0    1  117.0  56.0  3.8  111.0  11.2
# 4  51.0  80.0  1.010  2.0  0.0    1   1    0  106.0  26.0  1.4  138.0  11.6
#
#     pcv   rc  htn  dm  cad  appet  pe  ane
# 0  44.0  5.2    1   1    0      0   0    0
# 1  38.0  4.8    0   0    0      0   0    0
# 2  31.0  4.8    0   1    0      1   0    1
# 3  32.0  3.9    1   0    0      1   1    1
# 4  35.0  4.6    0   0    0      0   0    0

# %% [markdown]
# ### **Applying Scaling Technique**

# %%
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()
x_smote=sc.fit_transform(x_smote)

# %%
pd.DataFrame(x_smote,columns=sc.get_feature_names_out())
# Out:
#           age        bp        sg        al        su       rbc        pc  \
# 0   -0.137275  0.344068  0.246285  0.228193 -0.335309  0.322107  0.423374
# 1   -2.584265 -2.018495  0.246285  2.673124 -0.335309  0.322107  0.423374
# 2    0.698283  0.344068 -1.637426  1.043170  2.848005  0.322107  0.423374
# 3   -0.137275 -0.443453 -2.579281  2.673124 -0.335309  0.322107 -2.361980
# 4    0.041773  0.344068 -1.637426  1.043170 -0.335309  0.322107  0.423374
# ..        ...       ...       ...       ...       ...       ...       ...
# 495 -0.555070 -0.443453  1.188140 -0.586783 -0.335309  0.322107  0.423374
# 496 -0.713503 -1.230974  0.349083 -0.586783 -0.335309  0.322107  0.423374
# 497 -0.617132 -1.079792  0.427095 -0.586783 -0.335309  0.322107  0.423374
# 498  1.772571  0.069554  0.859827 -0.586783 -0.335309  0.322107  0.423374
# 499 -0.459376 -1.230974  0.968860 -0.586783 -0.335309  0.322107  0.423374
#
#           pcc       bgr        bu        sc       sod      hemo       pcv  \
# ...

# %% [markdown]
# # **Finding a Best Model with Best Random State**

# %% [markdown]
# ### **1.Logistic Regression**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import *

best_score=0
for i in range(43):
  x_train,x_test,y_train,y_test=train_test_split(x_smote,y_smote,test_size=0.2,random_state=i)
  lr=LogisticRegression()
  lr.fit(x_train,y_train)
  lr.predict_proba(x_test)[:,1]
  auc_score=roc_auc_score(y_test,lr.predict_proba(x_test)[:,1])

  if auc_score > best_score:
      best_score=auc_score
      best_rs=i
print(f'ran:{best_rs},auc_score:{best_score}')
# Out:
# ran:2,auc_score:1.0

# %% [markdown]
# **Evaluation Metrics**

# %%
# i am ok with this model and the evaluation Metrics looks greate so i selected this model...

x_train,x_test,y_train,y_test=train_test_split(x_smote,y_smote,test_size=0.2,random_state=2)
lr=LogisticRegression()
lr.fit(x_train,y_train)


cm=confusion_matrix(y_test,lr.predict(x_test))
ac=accuracy_score(y_test,lr.predict(x_test))
pr=precision_score(y_test,lr.predict(x_test))
re=recall_score(y_test,lr.predict(x_test))
f1=f1_score(y_test,lr.predict(x_test))
auc=roc_auc_score(y_test,lr.predict_proba(x_test)[:,1])

print(f'Accuracy Score: {ac}')
print(f'Precision Score: {pr}')
print(f'Recall Score: {re}')
print(f'F1 Score: {f1}')
print(f'Confusion Matrix: \n{cm}')
print(f'AUC: {auc}')

import matplotlib.pyplot as plt

y_hat=lr.predict_proba(x_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,y_hat)

plt.plot(fpr,tpr,label=f'AUC={auc}')
plt.plot([0,1],[0,1],linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# Out:
# Accuracy Score: 0.99
# Precision Score: 1.0
# Recall Score: 0.9791666666666666
# F1 Score: 0.9894736842105263
# Confusion Matrix:
# [[52  0]
#  [ 1 47]]
# AUC: 1.0

# %% [markdown]
# ## **Save The Model**

# %%
import pickle

with open('model_2.pkl','wb') as f:
  pickle.dump(lr,f)

# %%
with open('encoder_2.pkl','wb') as e:
  pickle.dump(le,e)

# %%
with open('scaler_2.pkl','wb') as j:
  pickle.dump(sc,j)
